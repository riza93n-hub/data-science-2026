# %% [markdown]
# <a href="https://colab.research.google.com/github/riza93n-hub/data-science-2026/blob/main/Pertemuan1_RIZA_250401020014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aktivitas Hands On Pertemuan 1
# **Nama Mahasiswa:** RIZA
# **NIM:** 250401020014
# **Kelas:** IF401

# %%
# Output sederhana
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
# Variabel & tipe data
nama = "Mahasiswa Informatika"
angkatan = "2025"
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Mahasiswa Informatika angkatan 2025!

# %%
# List & perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. Github

# %%
# Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Riza", "Informatika", 2025))
# Out:
# Riza | Informatika | 2025

# %% [markdown]
# ## Kesimpulan
#
# * **Apa yang Dipelajari:** Di pertemuan awal ini, saya belajar kembali dasar-dasar pemrograman Python yang nantinya akan sering dipakai untuk mengolah data. Saya mempraktikkan cara menampilkan teks ke layar, membuat dan menyimpan informasi dalam variabel, membuat daftar cetakan otomatis (perulangan), sampai membuat rumus atau fungsi siap pakai agar kode program tidak perlu ditulis berulang-ulang.
# * **Temuan Utama:** Menulis kode di Python ternyata cukup sederhana dan bahasanya mudah dipahami karena mirip dengan bahasa sehari-hari. Kita bisa dengan mudah menggabungkan teks dengan angka tanpa rumus yang ribet. Selain itu, penggunaan Google Colab dan GitHub dari awal ini sangat membantu karena kita bisa langsung mengetik dan menyimpan tugas kuliah secara online tanpa perlu instalasi aplikasi di laptop.
# * **Keterbatasan / Pertanyaan yang Muncul:** * *Keterbatasan:* Contoh program yang dibuat di atas masih sangat sederhana dan datanya masih diketik manual satu per satu di dalam kode, belum memakai data asli yang banyak.
#   * *Pertanyaan:* Bagaimana caranya agar kode Python yang sudah kita buat ini bisa membaca dan mengolah dokumen data yang ukurannya besar, seperti file Excel atau tabel buatan dari luar?
